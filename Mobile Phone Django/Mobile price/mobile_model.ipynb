# %% [markdown]
# # Mobile App

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\my pc\Desktop\Mobile Phone Django\Mobile price\train.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
print(df['price_range'].unique())
# Out:
# [1 2 3 0]

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
correlation_mat=df.corr()
plt.figure(figsize=(18,10))
sns.heatmap(correlation_mat,annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
X=df.drop('price_range',axis=1)
y=df['price_range']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=250,n_jobs=1)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=250, n_jobs=1)

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 1, 2, 0, 2, 2, 0, 2, 1, 3, 2, 3, 0, 1, 0, 3, 1, 0, 0, 0, 2, 2,
#        0, 2, 3, 0, 3, 1, 0, 0, 0, 0, 3, 2, 2, 2, 3, 2, 0, 3, 1, 3, 3, 0,
#        3, 3, 2, 1, 0, 0, 1, 3, 2, 2, 0, 2, 3, 3, 0, 0, 3, 3, 3, 0, 0, 1,
#        1, 3, 2, 3, 0, 0, 2, 2, 1, 0, 0, 1, 0, 2, 2, 2, 0, 0, 0, 3, 1, 1,
#        2, 2, 0, 2, 2, 0, 3, 0, 0, 2, 1, 2, 1, 3, 0, 3, 1, 1, 1, 2, 1, 3,
#        2, 0, 0, 1, 2, 1, 1, 1, 0, 3, 1, 1, 3, 3, 3, 0, 3, 2, 0, 2, 0, 2,
#        3, 2, 3, 1, 1, 3, 3, 2, 1, 1, 3, 0, 1, 0, 1, 1, 3, 1, 0, 3, 0, 1,
#        2, 1, 0, 2, 0, 3, 3, 3, 0, 3, 3, 3, 0, 1, 3, 3, 0, 2, 1, 0, 2, 0,
#        0, 2, 1, 2, 2, 3, 0, 3, 2, 1, 0, 2, 2, 3, 3, 3, 0, 1, 0, 0, 3, 1,
#        0, 3, 2, 1, 1, 1, 2, 2, 0, 3, 1, 3, 3, 1, 1, 0, 2, 3, 3, 1, 2, 0,
#        1, 0, 1, 0, 3, 0, 2, 0, 1, 2, 2, 0, 3, 0, 1, 2, 3, 1, 0, 2, 2, 1,
#        1, 0, 0, 1, 3, 3, 3, 1, 0, 0, 0, 0, 0, 1, 0, 1, 1, 2, 3, 3, 2, 0,
#        1, 3, 0, 3, 1, 1, 3, 3, 2, 0, 3, 2, 3, 0, 1, 3, 3, 1, 3, 1, 0, 2,
# ...

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.9025

# %%
classification_rep=classification_report(y_test,y_pred)
print("classification_report:\n ",classification_rep)
# Out:
# classification_report:
#                 precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       105
#            1       0.87      0.87      0.87       101
#            2       0.84      0.84      0.84        87
#            3       0.95      0.93      0.94       107
#
#     accuracy                           0.90       400
#    macro avg       0.90      0.90      0.90       400
# weighted avg       0.90      0.90      0.90       400

# %%
confusion=confusion_matrix(y_test,y_pred)
print("Confusion Matrix: \n",confusion)
# Out:
# Confusion Matrix:
#  [[101   4   0   0]
#  [  7  88   6   0]
#  [  0   9  73   5]
#  [  0   0   8  99]]

# %%
from joblib import dump

# %%
dump(model,'./../Mobile price/model.joblib')
# Out:
# ['./../Mobile price/model.joblib']
